# %% [markdown]
# <a href="https://colab.research.google.com/github/RakaiSeto/21_TI-3G-ML/blob/main/UTS_2341720135_Rakai_Seto_Sembodo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install annoy
# Out:
# Collecting annoy
#   Downloading annoy-1.17.3.tar.gz (647 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.5/647.5 kB 11.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: annoy
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.17.3-cp312-cp312-linux_x86_64.whl size=551810 sha256=e5f0bc38a8c17c862de76a5da1c037a4d54f889bce67b50860dd15216ac1a297
#   Stored in directory: /root/.cache/pip/wheels/db/b9/53/a3b2d1fe1743abadddec6aa541294b24fdbc39d7800bc57311
# Successfully built annoy
# Installing collected packages: annoy
# Successfully installed annoy-1.17.3

# %%
import pandas as pd
import numpy as np
import random
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from annoy import AnnoyIndex
from IPython.display import display
import warnings
warnings.filterwarnings('ignore')

# Inisialisasi seed agar hasil replikasi konsisten
SEED = 24
random.seed(SEED)
np.random.seed(SEED)

# Muat dataset
df = pd.read_csv('/content/heart.csv')

print("="*80)
print("ANALISIS CLUSTERING DATASET PENYAKIT JANTUNG")
print("="*80)

# 1. Eksplorasi Awal Dataset
print("\n1. INFORMASI DATASET")
print("-" * 50)
print(f"Jumlah baris data   : {df.shape[0]}")
print(f"Jumlah kolom fitur  : {df.shape[1]}")

print("\nContoh 5 baris pertama:")
display(df.head())

print("\nStatistik deskriptif fitur numerik:")
display(df.describe())

# 2. Tahap Persiapan Data
print("\n2. PREPROCESSING DATA")
print("-" * 50)

# 2.1 Cek nilai kosong
print("Jumlah missing value per kolom:")
print(df.isnull().sum())

# 2.2 Tambahkan fitur turunan
df['chol_age'] = df['chol'] * df['age']
print("\nFitur tambahan 'chol_age' berhasil dibuat.")
print(f"Nilai minimum: {df['chol_age'].min():.1f}, maksimum: {df['chol_age'].max():.1f}, rata-rata: {df['chol_age'].mean():.1f}")

# 2.3 Standarisasi fitur numerik
num_features = ["age", "trestbps", "chol", "thalach", "oldpeak", "chol_age"]
scaler = StandardScaler()
df[num_features] = scaler.fit_transform(df[num_features])
print(f"\nFitur numerik ({len(num_features)} kolom) telah distandarkan.")

# 3. Analisis Clustering
print("\n3. ANALISIS CLUSTERING")
print("-" * 50)

# 3.1 Pemilihan Jumlah Cluster Optimal (K-Means)
print("3.1 Menentukan jumlah cluster terbaik")
wcss = []
sil_scores = []
K_candidates = range(1, 11)

for k in K_candidates:
    model = KMeans(n_clusters=k, random_state=SEED)
    model.fit(df)
    wcss.append(model.inertia_)

    if k > 1:
        labels = model.predict(df)
        sil = silhouette_score(df, labels)
        sil_scores.append(sil)
        print(f"k={k}: Inertia={model.inertia_:.2f}, Silhouette={sil:.4f}")

# Visualisasi Elbow & Silhouette
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(K_candidates, wcss, 'bo-')
plt.xlabel('Jumlah Cluster (k)')
plt.ylabel('WCSS (Inertia)')
plt.title('Elbow Method')
plt.grid(alpha=0.3)

plt.subplot(1, 2, 2)
plt.plot(range(2, 11), sil_scores, 'ro-')
plt.xlabel('Jumlah Cluster (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Method')
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# 3.2 K-Means dengan k=2
print("\n3.2 Penerapan K-Means (k=2)")
kmeans = KMeans(n_clusters=2, random_state=SEED)
kmeans_labels = kmeans.fit_predict(df)
sil_kmeans = silhouette_score(df, kmeans_labels)
db_kmeans = davies_bouldin_score(df, kmeans_labels)

print(f"Cluster terbentuk: {len(set(kmeans_labels))}")
print(f"Silhouette Score: {sil_kmeans:.4f}")
print(f"Davies-Bouldin Index: {db_kmeans:.4f}")

# 3.3 DBSCAN
print("\n3.3 Penerapan DBSCAN")
neighbors = NearestNeighbors(n_neighbors=5).fit(df)
dists, _ = neighbors.kneighbors(df)
sorted_dists = np.sort(dists[:, 4])

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(sorted_dists)
plt.xlabel("Urutan titik")
plt.ylabel("Jarak tetangga ke-5")
plt.title("Menentukan epsilon untuk DBSCAN")
plt.grid(alpha=0.3)

dbscan = DBSCAN(eps=2, min_samples=5)
dbscan_labels = dbscan.fit_predict(df)

plt.subplot(1, 2, 2)
unique, counts = np.unique(dbscan_labels, return_counts=True)
plt.bar(unique, counts, color=['red' if x == -1 else 'blue' for x in unique])
plt.xlabel('Cluster')
plt.ylabel('Jumlah Data')
plt.title('Distribusi DBSCAN')
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

n_dbscan_clusters = len(set(dbscan_labels)) - (1 if -1 in dbscan_labels else 0)
n_noise = list(dbscan_labels).count(-1)
print(f"Jumlah cluster DBSCAN: {n_dbscan_clusters}")
print(f"Jumlah noise points   : {n_noise}")

if n_dbscan_clusters > 1:
    sil_dbscan = silhouette_score(df, dbscan_labels)
    db_dbscan = davies_bouldin_score(df, dbscan_labels)
    print(f"Silhouette Score: {sil_dbscan:.4f}")
    print(f"Davies-Bouldin Index: {db_dbscan:.4f}")
else:
    sil_dbscan = np.nan
    db_dbscan = np.nan
    print("Silhouette dan DB Index tidak dapat dihitung (cluster tunggal).")

# 3.4 Visualisasi Cluster
print("\n3.4 Visualisasi Cluster")
pca = PCA(n_components=2)
pca_data = pca.fit_transform(df)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sc1 = plt.scatter(pca_data[:, 0], pca_data[:, 1], c=kmeans_labels, cmap='viridis', alpha=0.7)
plt.colorbar(sc1)
plt.title('K-Means Clustering (k=2)')
plt.grid(alpha=0.3)

plt.subplot(1, 2, 2)
sc2 = plt.scatter(pca_data[:, 0], pca_data[:, 1], c=dbscan_labels, cmap='Set3', alpha=0.7)
plt.colorbar(sc2)
plt.title('DBSCAN Clustering')
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# 3.5 Perbandingan Model
print("\n3.5 Perbandingan Algoritma")
print("="*60)
comparison = pd.DataFrame({
    'Metode': ['K-Means', 'DBSCAN'],
    'Silhouette': [sil_kmeans, sil_dbscan],
    'Davies-Bouldin': [db_kmeans, db_dbscan],
    'Jumlah Cluster': [len(set(kmeans_labels)), n_dbscan_clusters],
    'Noise Points': [0, n_noise]
})
display(comparison.round(3))

# 4. Annoy untuk Nearest Neighbor
print("\n4. PENERAPAN ANNOY")
print("-" * 50)

f = df.shape[1]
annoy_idx = AnnoyIndex(f, 'euclidean')

for i, vec in enumerate(df.values):
    annoy_idx.add_item(i, vec)

annoy_idx.build(10)
print("Annoy index selesai dibuat (10 trees)")

# Query sample NN
query_idx = np.random.choice(len(df), 3, replace=False)
print("\nHASIL NEAREST NEIGHBOR QUERY")
print("="*70)

for q_i, q_idx in enumerate(query_idx, 1):
    neighbors, dists = annoy_idx.get_nns_by_item(q_idx, 5, include_distances=True)
    q_row = df.iloc[q_idx]

    print(f"\nQuery {q_i} (Index {q_idx})")
    print(f"Cluster: {kmeans_labels[q_idx]}")
    print(f"age={q_row['age']:.2f}, trestbps={q_row['trestbps']:.2f}, chol={q_row['chol']:.2f}")

    print(f"\n{'Rank':<4} {'Idx':<8} {'Dist':<12} {'Cluster':<8} {'Age':<8} {'Chol':<8}")
    print("-" * 60)
    for r, (nid, dist) in enumerate(zip(neighbors, dists), 1):
        nrow = df.iloc[nid]
        print(f"{r:<4} {nid:<8} {dist:<12.4f} {kmeans_labels[nid]:<8} {nrow['age']:<8.2f} {nrow['chol']:<8.2f}")
    print("-" * 60)

# 5. Kesimpulan
print("\n5. KESIMPULAN")
print("-" * 50)
print(f"Dataset memiliki {df.shape[0]} sampel dan {df.shape[1]} fitur.")
print(f"K-Means (k=2) memberikan Silhouette Score tertinggi ({sil_kmeans:.3f}).")
print(f"DBSCAN mendeteksi {n_dbscan_clusters} cluster dan {n_noise} noise points.")
print("Annoy memungkinkan pencarian tetangga terdekat secara efisien.")
print("\nSaran: Gunakan K-Means untuk segmentasi awal pasien, dan Annoy untuk pencarian kemiripan data secara cepat.")
print("="*80)
# Out:
# ================================================================================
# ANALISIS CLUSTERING DATASET PENYAKIT JANTUNG
# ================================================================================
#
# 1. INFORMASI DATASET
# --------------------------------------------------
# Jumlah baris data   : 1025
# Jumlah kolom fitur  : 14
#
# Contoh 5 baris pertama:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
# Statistik deskriptif fitur numerik:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000
# 2. PREPROCESSING DATA
# --------------------------------------------------
# Jumlah missing value per kolom:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64
#
# Fitur tambahan 'chol_age' berhasil dibuat.
# Nilai minimum: 5916.0, maksimum: 37788.0, rata-rata: 13493.6
#
# Fitur numerik (6 kolom) telah distandarkan.
#
# 3. ANALISIS CLUSTERING
# --------------------------------------------------
# 3.1 Menentukan jumlah cluster terbaik
# k=2: Inertia=8241.55, Silhouette=0.1847
# k=3: Inertia=7458.59, Silhouette=0.1713
# k=4: Inertia=6962.99, Silhouette=0.1133
# k=5: Inertia=6620.95, Silhouette=0.1118
# k=6: Inertia=6367.51, Silhouette=0.1207
# k=7: Inertia=6056.07, Silhouette=0.1135
# k=8: Inertia=5826.35, Silhouette=0.1240
# k=9: Inertia=5682.38, Silhouette=0.1277
# k=10: Inertia=5478.87, Silhouette=0.1321
# 3.2 Penerapan K-Means (k=2)
# Cluster terbentuk: 2
# Silhouette Score: 0.1847
# Davies-Bouldin Index: 1.9687
#
# 3.3 Penerapan DBSCAN
# Jumlah cluster DBSCAN: 13
# Jumlah noise points   : 346
# Silhouette Score: -0.1008
# Davies-Bouldin Index: 1.9132
#
# 3.4 Visualisasi Cluster
# 3.5 Perbandingan Algoritma
# ============================================================
#     Metode  Silhouette  Davies-Bouldin  Jumlah Cluster  Noise Points
# 0  K-Means       0.185           1.969               2             0
# 1   DBSCAN      -0.101           1.913              13           346
# 4. PENERAPAN ANNOY
# --------------------------------------------------
# Annoy index selesai dibuat (10 trees)
#
# HASIL NEAREST NEIGHBOR QUERY
# ======================================================================
#
# Query 1 (Index 642)
# Cluster: 1
# age=1.05, trestbps=-0.21, chol=0.33
#
# Rank Idx      Dist         Cluster  Age      Chol
# ------------------------------------------------------------
# 1    38       0.0000       1        1.05     0.33
# 2    642      0.0000       1        1.05     0.33
# 3    983      0.0000       1        1.05     0.33
# 4    305      2.0475       1        0.83     0.41
# 5    650      2.0475       1        0.83     0.41
# ------------------------------------------------------------
#
# Query 2 (Index 628)
# Cluster: 1
# age=1.61, trestbps=0.48, chol=-0.14
#
# Rank Idx      Dist         Cluster  Age      Chol
# ------------------------------------------------------------
# 1    628      0.0000       1        1.61     -0.14
# 2    942      0.0000       1        1.61     -0.14
# 3    959      0.0000       1        1.61     -0.14
# 4    142      2.1776       1        0.72     -0.23
# 5    623      2.1776       1        0.72     -0.23
# ------------------------------------------------------------
#
# Query 3 (Index 392)
# Cluster: 0
# age=-0.38, trestbps=-1.23, chol=-1.38
#
# Rank Idx      Dist         Cluster  Age      Chol
# ------------------------------------------------------------
# 1    369      0.0000       0        -0.38    -1.38
# 2    385      0.0000       0        -0.38    -1.38
# 3    392      0.0000       0        -0.38    -1.38
# 4    161      2.1286       0        -0.38    -0.47
# 5    745      2.1286       0        -0.38    -0.47
# ------------------------------------------------------------
#
# 5. KESIMPULAN
# --------------------------------------------------
# Dataset memiliki 1025 sampel dan 15 fitur.
# K-Means (k=2) memberikan Silhouette Score tertinggi (0.185).
# DBSCAN mendeteksi 13 cluster dan 346 noise points.
# Annoy memungkinkan pencarian tetangga terdekat secara efisien.
#
# Saran: Gunakan K-Means untuk segmentasi awal pasien, dan Annoy untuk pencarian kemiripan data secara cepat.
# ================================================================================
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Silhouette'].plot(kind='hist', bins=20, title='Silhouette')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Davies-Bouldin'].plot(kind='hist', bins=20, title='Davies-Bouldin')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Jumlah Cluster'].plot(kind='hist', bins=20, title='Jumlah Cluster')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Noise Points'].plot(kind='hist', bins=20, title='Noise Points')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Metode').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Silhouette', y='Davies-Bouldin', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Davies-Bouldin', y='Jumlah Cluster', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Jumlah Cluster', y='Noise Points', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Jumlah Cluster']
#   ys = series['Silhouette']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('Jumlah Cluster', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Metode')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Metode', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Jumlah Cluster')
# _ = plt.ylabel('Silhouette')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Jumlah Cluster']
#   ys = series['Davies-Bouldin']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('Jumlah Cluster', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Metode')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Metode', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Jumlah Cluster')
# _ = plt.ylabel('Davies-Bouldin')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Jumlah Cluster']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Jumlah Cluster'}, axis=1)
#               .sort_values('Jumlah Cluster', ascending=True))
#   xs = counted['Jumlah Cluster']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('Jumlah Cluster', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Metode')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Metode', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Jumlah Cluster')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Noise Points']
#   ys = series['Silhouette']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('Noise Points', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Metode')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Metode', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Noise Points')
# _ = plt.ylabel('Silhouette')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['Silhouette'].plot(kind='line', figsize=(8, 4), title='Silhouette')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['Davies-Bouldin'].plot(kind='line', figsize=(8, 4), title='Davies-Bouldin')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Jumlah Cluster'].plot(kind='line', figsize=(8, 4), title='Jumlah Cluster')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['Noise Points'].plot(kind='line', figsize=(8, 4), title='Noise Points')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_16['Metode'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_16, x='Silhouette', y='Metode', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['Metode'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='Davies-Bouldin', y='Metode', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['Metode'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='Jumlah Cluster', y='Metode', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['Metode'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='Noise Points', y='Metode', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
